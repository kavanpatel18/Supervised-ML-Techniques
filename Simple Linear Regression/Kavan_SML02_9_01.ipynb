# %%
#Importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#Load Iris dataset
iris = load_iris()
x = iris.data[:, 0]. reshape(-1,1) #Using sepal length as feature(index=0)
y = iris.data[:, 2] #Petal length as target(index=2)

#Splitting into training and test set
x_train, x_test, y_train, y_test = train_test_split(x ,y , test_size=0.2, random_state=42) #80% training 20%testing

#x_train, x_temp, y_train, t_temp = train_test_split(x, y, test_size=0.3, random_state=42)
#x_val, x_test, y_val, y_test = train_test_split(x, y, test_size=0.5, random_state=42)

# %%
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#Initializing the Linear Regression Model
model = LinearRegression()

model.fit(x_train, y_train)

#Making Predictions
y_pred = model.predict(x_test)

#Calculate the MSE (Mean squared error) as a metrix
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error: ", mse)

print("Test R2 Score: ", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error:  0.5960765879745186
# Test R2 Score:  0.8181245472591437

# %%
#Visualizing the data and the regression line
plt.scatter(x_test, y_test, color = 'red', label='Test Data')
plt.plot(x_test, y_pred, color = 'blue', label='Regression Line')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Linear Regression Model on Iris Dataset')
plt.legend()
plt.show()

# %%
#Print the coefficients (intercept and slope)
print(f"Intercept: {model.intercept_}")
print(f"Slope: {model.coef_[0]}")
print(f"Mean squared error: {mse}")
# Out:
# Intercept: -6.927127731475695
# Slope: 1.8339625990203465
# Mean squared error: 0.5960765879745186

# %%
import pandas as pd

# Convert the iris data to a pandas DataFrame for easier viewing
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris = load_iris()
x = iris.data[:, 1]. reshape(-1,1) #Using sepal length as feature(index=0)
y = iris.data[:, 3] #Petal length as target(index=2)

#Splitting into training and test set
x_train, x_test, y_train, y_test = train_test_split(x ,y , test_size=0.2, random_state=42) #80% training 20%testing

#x_train, x_temp, y_train, t_temp = train_test_split(x, y, test_size=0.3, random_state=42)
#x_val, x_test, y_val, y_test = train_test_split(x, y, test_size=0.5, random_state=42)

# %%
#Initializing the Linear Regression Model
model = LinearRegression()

model.fit(x_train, y_train)

#Making Predictions
y_pred = model.predict(x_test)

#Calculate the MSE (Mean squared error) as a metrix
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error: ", mse)

print("Test R2 Score: ", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error:  0.5617835897948079
# Test R2 Score:  0.11621382856661178

# %%
#Visualizing the data and the regression line
plt.scatter(x_test, y_test, color = 'red', label='Test Data')
plt.plot(x_test, y_pred, color = 'blue', label='Regression Line')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.title('Linear Regression Model on Iris Dataset')
plt.legend()
plt.show()

# %%
#Print the coefficients (intercept and slope)
print(f"Intercept: {model.intercept_}")
print(f"Slope: {model.coef_[0]}")
print(f"Mean squared error: {mean_squared_error(y_test, y_pred)}")
# Out:
# Intercept: 3.0783005374178947
# Slope: -0.618933218536057
# Mean squared error: 10.1963420970599
